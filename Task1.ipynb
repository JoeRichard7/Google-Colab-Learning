# %% [markdown]
# <a href="https://colab.research.google.com/github/JoeRichard7/Google-Colab-Learning/blob/master/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('students.csv')
# print(df.to_string())   --> Prints all the rows
# df    --> Prints all the rows
df.head()
# Out:
#       Name  Age  Gender  Marks        City  Attendance
# 0     Arun   20    Male     85     Chennai        90.0
# 1    Priya   21  Female     90  Coimbatore        95.0
# 2  Karthik   22    Male     76     Madurai         NaN
# 3    Divya   20  Female     88     Chennai        85.0
# 4    Rahul   23    Male     92      Trichy        88.0
